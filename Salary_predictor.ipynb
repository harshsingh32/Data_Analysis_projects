# %% [markdown]
# <a href="https://colab.research.google.com/github/harshsingh32/Data_Analysis_projects/blob/main/Salary_predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install word2number
import pandas as pd
import matplotlib.pyplot as plt
from word2number import w2n
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5566 sha256=eb69649a74831849849fa4e053cc2a188f917282f23e9f46def22fe74537e9bb
#   Stored in directory: /root/.cache/pip/wheels/84/ff/26/d3cfbd971e96c5aa3737ecfced81628830d7359b55fbb8ca3b
# Successfully built word2number
# ...

# %%
df = pd.read_csv('/content/expected_salary.csv')
df
# Out:
#   experience  test_score  interview_score  salary
# 0        NaN         8.0                9   50000
# 1        NaN         8.0                6   45000
# 2       five         6.0                7   60000
# 3        two        10.0               10   65000
# 4      seven         9.0                6   70000
# 5      three         7.0               10   62000
# 6        ten         NaN                7   72000
# 7     eleven         7.0                8   80000

# %%
df.experience = df.experience.fillna('zero')
df
# Out:
#   experience  test_score  interview_score  salary
# 0       zero         8.0                9   50000
# 1       zero         8.0                6   45000
# 2       five         6.0                7   60000
# 3        two        10.0               10   65000
# 4      seven         9.0                6   70000
# 5      three         7.0               10   62000
# 6        ten         NaN                7   72000
# 7     eleven         7.0                8   80000

# %%
df.experience = df.experience.apply(w2n.word_to_num)

# %%
df
# Out:
#    experience  test_score  interview_score  salary
# 0           0         8.0                9   50000
# 1           0         8.0                6   45000
# 2           5         6.0                7   60000
# 3           2        10.0               10   65000
# 4           7         9.0                6   70000
# 5           3         7.0               10   62000
# 6          10         NaN                7   72000
# 7          11         7.0                8   80000

# %%
df.test_score = df.test_score.fillna(df.test_score.median())
df
# Out:
#    experience  test_score  interview_score  salary
# 0           0         8.0                9   50000
# 1           0         8.0                6   45000
# 2           5         6.0                7   60000
# 3           2        10.0               10   65000
# 4           7         9.0                6   70000
# 5           3         7.0               10   62000
# 6          10         8.0                7   72000
# 7          11         7.0                8   80000

# %%
df.test_score.median()
# Out:
# 8.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   experience       8 non-null      int64
#  1   test_score       8 non-null      float64
#  2   interview_score  8 non-null      int64
#  3   salary           8 non-null      int64
# dtypes: float64(1), int64(3)
# memory usage: 384.0 bytes

# %%
df.experience = df.experience.astype(int)
df
# Out:
#    experience  test_score  interview_score  salary
# 0           0         8.0                9   50000
# 1           0         8.0                6   45000
# 2           5         6.0                7   60000
# 3           2        10.0               10   65000
# 4           7         9.0                6   70000
# 5           3         7.0               10   62000
# 6          10         8.0                7   72000
# 7          11         7.0                8   80000

# %%
df.test_score = df.test_score.astype(int)
df
# Out:
#    experience  test_score  interview_score  salary
# 0           0           8                9   50000
# 1           0           8                6   45000
# 2           5           6                7   60000
# 3           2          10               10   65000
# 4           7           9                6   70000
# 5           3           7               10   62000
# 6          10           8                7   72000
# 7          11           7                8   80000

# %%
df.describe()
# Out:
#        experience  test_score  interview_score       salary
# count     8.00000    8.000000         8.000000      8.00000
# mean      4.75000    7.875000         7.875000  63000.00000
# std       4.26782    1.246423         1.642081  11501.55269
# min       0.00000    6.000000         6.000000  45000.00000
# 25%       1.50000    7.000000         6.750000  57500.00000
# 50%       4.00000    8.000000         7.500000  63500.00000
# 75%       7.75000    8.250000         9.250000  70500.00000
# max      11.00000   10.000000        10.000000  80000.00000

# %%
# %matplotlib inline
plt.title('Graph')
plt.xlabel('Experience ')
plt.ylabel('salary')
plt.bar(df.experience, df.salary)
# Out:
# <BarContainer object of 8 artists>

# %%
plt.xlabel('Experience ')
plt.ylabel('salary')
plt.plot(df.experience, df.salary)

# %%
from sklearn import linear_model

# %%
model = linear_model.LinearRegression()

# %%
input_data = df.drop(columns='salary')
output_data = df.salary

# %%
input_data
# Out:
#    experience  test_score  interview_score
# 0           0           8                9
# 1           0           8                6
# 2           5           6                7
# 3           2          10               10
# 4           7           9                6
# 5           3           7               10
# 6          10           8                7
# 7          11           7                8

# %%
output_data
# Out:
# 0    50000
# 1    45000
# 2    60000
# 3    65000
# 4    70000
# 5    62000
# 6    72000
# 7    80000
# Name: salary, dtype: int64

# %%
model.fit(input_data,output_data)
# Out:
# LinearRegression()

# %%
model.predict([[2,1,2]])
